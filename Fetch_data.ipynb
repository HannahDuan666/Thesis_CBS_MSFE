# %% [markdown]
# # Download and import packages

# %%
import wrds
import pandas as pd
import calendar
import numpy as np
import time
import unicodedata
import re
from functools import partial
from nltk.corpus import stopwords
import textstat
from nltk.tokenize import sent_tokenize
from nltk.stem.snowball import SnowballStemmer
stemmer=SnowballStemmer(language='english')
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from multiprocessing import Pool
from nltk.sentiment.util import mark_negation
import docx
from docx.shared import Pt
import warnings
import datetime
import sys
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
warnings.filterwarnings('ignore')

# %%
# Get the list of company ids that we are interested in
gvkey = pd.read_csv('gvkey.csv')
gvkey_companyid = pd.merge(gvkey, ID_Mapping_Table[['companyid', 'gvkey']], on='gvkey', how='left')
companyid_list = gvkey_companyid[gvkey_companyid['companyid'].notna()]['companyid'].astype(int).tolist()

# %% [markdown]
# # Extract 10-year earnings call data and save it

# %%
def load_all_earnings_calls(db,year,month):
    '''
    This function returns all call IDs that occurred in a given time interval.  Note the
    passed in dates are interpreted as UTC dates, which doesn't matter much because the
    month level aggregation happens later, and will be done by NY time presumably.

    year, month -- numerical value of month to load
    '''
    def status(objin):
        print('\tRows in month: {:,}'.format(objin.shape[0]))


    # select all id's that appear in this month, as well as any records with these id's in other
    # months; the mostimportantdateutc field is the date of the call, but calls often get revised
    # in the following months

    relevant_columns = '''companyid, keydevid, transcriptid, headline, keydeveventtypename,
                          transcriptcollectiontypeid, transcriptcreationdate_utc'''
    sql_query = '''
    select {} from ciq.wrds_transcript_detail
    where mostimportantdateutc between '{}-{:02d}-{:02d}' and '{}-{:02d}-{}'
    '''.format(relevant_columns, year,month,1,year,month,calendar.monthrange(year,month)[1])

    print('Doing fetch',sql_query)
    calls = db.raw_sql(sql_query)

    # select the right type of calls
    calls = calls[calls.keydeveventtypename == 'Earnings Calls']
    print('\tFound {:,} calls'.format(len(calls.groupby('keydevid'))))
    status(calls)

    # save all the companyIDs of a transcript into a list, one transcript may mention two or more companies
    # drop for a while, merge back at the end of the whole process
    calls.companyid = calls.companyid.apply(lambda x :int(x))
    companyIDs = calls.groupby('keydevid')['companyid'].unique().reset_index()
    calls.drop('companyid', axis=1, inplace=True)

    # now select the most recent observation and the highest transcriptcollectiontypeid
    def select_type(obj):
        # take the last observations
        last_date = obj.transcriptcreationdate_utc.unique().max()

        # take the largest available transcriptcollectiontypeid (allowable values are 1,2,7,8)
        # Select with priority from high to low as:
        # 8 (audited copy), 1 (proofed copy), 2 (edited copy), 7 (spell chekced copy)
        return(obj[obj.transcriptcreationdate_utc==last_date].sort_values('transcriptcollectiontypeid').\
               iloc[0])

    # select the correct version of each transcript
    calls = calls[calls['transcriptcollectiontypeid'].isin([1,2,7,8])]
    calls.transcriptcollectiontypeid=calls.transcriptcollectiontypeid.replace({8:1,1:2,2:3,7:4})
    calls = calls.groupby('keydevid').apply(select_type).reset_index(drop=True)
    status(calls)

    # Get the detailed time in the original event date from ciqkeydev db
    # mostimportantdateutc in the wrds_transcript_detail db does not provide specific time in a day
    sql_query2 = '''
    select keydevid, mostimportantdateutc from ciq.ciqkeydev where keydevid in
    (select keydevid from ciq.wrds_transcript_detail where
    mostimportantdateutc between '{}-{:02d}-{:02d}' and '{}-{:02d}-{}')
    '''.format(year,month,1,year,month,calendar.monthrange(year,month)[1])

    call_detail_time = db.raw_sql(sql_query2)
    calls = calls.merge(call_detail_time, on='keydevid', how='left')


    # for the selected calls, get the transcripts, and relevant information

    sql_query3 = '''
    SELECT transcriptid, componenttext, componentorder, transcriptcomponentid, transcriptcomponenttypeid, transcriptpersonid
    FROM ciq_transcripts.ciqtranscriptcomponent
    WHERE transcriptid in ({})
    ORDER BY transcriptid, componentorder
    '''.format(','.join(['{:.0f}'.format(el) for el in calls.transcriptid.unique()]))

    print('Selecting components from {:,} transcripts'.format(len(calls.transcriptid.unique())))
    comps = db.raw_sql(sql_query3)


    # Get Table for all personname
    sql_query4 = '''
    SELECT transcriptpersonid, transcriptpersonname
    FROM ciq_transcripts.ciqtranscriptperson
    '''
    speaker_info = db.raw_sql(sql_query4)
    speaker_info['transcriptpersonname_id'] = speaker_info['transcriptpersonname']\
        +speaker_info['transcriptpersonid'].apply(lambda x:'_<id: '+str(int(x))+'>')
    comps = pd.merge(comps,speaker_info,on='transcriptpersonid',how='left')
    comps['transcriptpersonname_id'] = comps['transcriptpersonname_id'].fillna('Unknown Person')

    # Now recover the presentation and Q&A sections
    # Break one transcript into blocks, for Presentations, divide into paragraphs ,
    # for QA, divide into question-answer pairs (Q and folloing As until next Q)
    # the presentation section has transcriptcomponenttypeid == 2, and the Q&A have 3&4 respectively;
    # NOTE: we combine the Q&A into one block of text, and do not differentiate between them
    def break_into_blocks(obj):
        obj = obj.sort_values(['transcriptid','componentorder'])

        # Presentations
        pre = obj[obj.transcriptcomponenttypeid.isin([2])]

        # Change the punctuations to split the transcripts into paragraphs
        pre['componenttext'] = pre['componenttext'].apply(lambda x: x.replace('\r\n', '\n').replace('\r', '\n').split('\n'))
        pre = pre.explode(column='componenttext')

        # In subsequent analysis, we use keydevid_transcriptid_section_blocknum as an identifier for each block
        pre['block_num'] = pre.groupby('transcriptid')['componenttext'].cumcount()
        pre['section'] = 'Pre'
        pre['pretty_text'] = '[Presentation] '+ pre['transcriptpersonname_id'] + '\n' + pre['componenttext']

        # QA
        qa = obj[obj.transcriptcomponenttypeid.isin([3,4])]
        qa['Ques'] = qa['transcriptcomponenttypeid']==3
        qa['transcriptpersonname_id'] = np.where(qa['Ques'], 'Q--' + qa['transcriptpersonname_id'].astype(str),'A--' + qa['transcriptpersonname_id'].astype(str))
        qa['block_num'] = qa['Ques'].cumsum() # cumsum only increases if there is a new question
        qa['pretty_text'] = qa['transcriptpersonname_id'] + '\n' + qa['componenttext']
        qablocks = qa.groupby(['block_num','transcriptid']).apply(lambda x: '\n'.join(x['componenttext'])).reset_index().rename(columns={0:'QA'})
        qablocks_pretty = qa.groupby(['block_num','transcriptid']).apply(lambda x: '\n'.join(x['pretty_text'])).reset_index().rename(columns={0:'QA_pretty'})

        qa = pd.merge(qa, qablocks, on=['block_num', 'transcriptid'], how='left') # merge the combined QA to original df
        qa = pd.merge(qa, qablocks_pretty, on=['block_num', 'transcriptid'], how='left')
        qa['componenttext'] = qa['QA']
        qa['pretty_text'] = '[Q&A] ' + qa['QA_pretty']

        qa = qa.sort_values(by=['transcriptid', 'componentorder'])
        qa = qa.drop_duplicates(['block_num','transcriptid'], keep='first')

        # In subsequent analysis, we use keydevid_transcriptid_section_blocknum as an identifier for each block
        qa['block_num'] = qa.groupby('transcriptid')['block_num'].cumcount()
        qa['section'] = 'QA'

        # return relevant columns
        relev_cols = ['transcriptid', 'componenttext', 'block_num', 'section','pretty_text']
        return pd.concat([pre[relev_cols], qa[relev_cols]])

    comps = break_into_blocks(comps)

    # drop irrelevant columns, merge companyids back and change variable types
    drop_columns = ['transcriptcreationdate_utc', 'transcriptcollectiontypeid', 'keydeveventtypename']
    calls = calls.drop(drop_columns, axis=1)
    calls = calls.merge(companyIDs, on='keydevid')
    int_columns = ['keydevid', 'transcriptid']
    calls[int_columns] = calls[int_columns].astype(int)
    calls = calls.merge(comps,on='transcriptid')

    # deal with transcripts with multiple companyids
    calls = calls.reset_index(drop=True)
    calls['companyid']=calls['companyid'].apply(lambda x:re.sub('\[|\]','',str(x)).strip().split(' '))

    # return the merged data
    calls['Id'] = calls.apply(lambda x:str(x['keydevid'])+'_'+str(x['transcriptid'])+'_'+
                                     str(x['section'])+'_'+str(x['block_num']), axis=1)
    return calls

# %%
def save_ec_data(year):

    """
    Fetch yearly earnings calls and extract Pres and QA blocks.
    Separate NA and nonNA fiirms.
    """

    start_year = year
    end_year = year
    start_month = 1
    end_month = 12

    monthly_df = []

    # Loop through the months
    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            if year == start_year and month < start_month:
                continue
            if year == end_year and month > end_month:
                break

            db = wrds.Connection(wrds_username='pengfei_ren')
            try:
                print(f'Fetching ECs from {year}-{month:02d} ...')
                data = load_all_earnings_calls(db, year, month)

                data['companyid'] = data['companyid'].apply(lambda x: x[0] if isinstance(x, list) and x else None)
                data['companyid'] = data['companyid'].astype(int)
                filtered_data = data[data['companyid'].isin(companyid_list)]
                monthly_df.append(filtered_data)
            except Exception as e:
                print(f'No data in {year}-{month:02d}: {e}')
            finally:
                db.close()

    # Combine all the monthly data into one DataFrame
    full_period_df = pd.concat(monthly_df)

    return full_period_df

# %%
for year in range(2015, 2024):
    annual_ec_data = save_ec_data(year)
    save_path = f'D:/EC_data/{year}_ec_data.parquet'
    annual_ec_data.to_parquet(save_path, index=False)
# Out:
# Loading library list...
# Done
# Fetching ECs from 2015-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-01-01' and '2015-01-31'
#
# 	Found 824 calls
# 	Rows in month: 2,857
# 	Rows in month: 824
# Selecting components from 824 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-02-01' and '2015-02-28'
#
# 	Found 2,636 calls
# 	Rows in month: 9,111
# 	Rows in month: 2,636
# Selecting components from 2,636 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-03-01' and '2015-03-31'
#
# 	Found 1,165 calls
# 	Rows in month: 3,956
# 	Rows in month: 1,165
# Selecting components from 1,165 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-04-01' and '2015-04-30'
#
# 	Found 1,765 calls
# 	Rows in month: 6,124
# 	Rows in month: 1,765
# Selecting components from 1,765 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-05-01' and '2015-05-31'
#
# 	Found 2,377 calls
# 	Rows in month: 8,113
# 	Rows in month: 2,377
# Selecting components from 2,377 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-06-01' and '2015-06-30'
#
# 	Found 257 calls
# 	Rows in month: 880
# 	Rows in month: 257
# Selecting components from 257 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-07-01' and '2015-07-31'
#
# 	Found 2,032 calls
# 	Rows in month: 7,070
# 	Rows in month: 2,032
# Selecting components from 2,032 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-08-01' and '2015-08-31'
#
# 	Found 2,363 calls
# 	Rows in month: 8,102
# 	Rows in month: 2,363
# Selecting components from 2,363 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-09-01' and '2015-09-30'
#
# 	Found 262 calls
# 	Rows in month: 914
# 	Rows in month: 262
# Selecting components from 262 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-10-01' and '2015-10-31'
#
# 	Found 1,731 calls
# 	Rows in month: 6,144
# 	Rows in month: 1,731
# Selecting components from 1,731 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-11-01' and '2015-11-30'
#
# 	Found 2,318 calls
# 	Rows in month: 8,235
# 	Rows in month: 2,318
# Selecting components from 2,318 transcripts
# Loading library list...
# Done
# Fetching ECs from 2015-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2015-12-01' and '2015-12-31'
#
# 	Found 251 calls
# 	Rows in month: 868
# 	Rows in month: 251
# Selecting components from 251 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-01-01' and '2016-01-31'
#
# 	Found 697 calls
# 	Rows in month: 2,491
# 	Rows in month: 697
# Selecting components from 697 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-02-01' and '2016-02-29'
#
# 	Found 2,710 calls
# 	Rows in month: 9,541
# 	Rows in month: 2,710
# Selecting components from 2,710 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-03-01' and '2016-03-31'
#
# 	Found 1,178 calls
# 	Rows in month: 4,038
# 	Rows in month: 1,178
# Selecting components from 1,178 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-04-01' and '2016-04-30'
#
# 	Found 1,586 calls
# 	Rows in month: 5,565
# 	Rows in month: 1,586
# Selecting components from 1,586 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-05-01' and '2016-05-31'
#
# 	Found 2,537 calls
# 	Rows in month: 9,328
# 	Rows in month: 2,537
# Selecting components from 2,537 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-06-01' and '2016-06-30'
#
# 	Found 242 calls
# 	Rows in month: 1,034
# 	Rows in month: 242
# Selecting components from 242 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-07-01' and '2016-07-31'
#
# 	Found 1,755 calls
# 	Rows in month: 7,375
# 	Rows in month: 1,755
# Selecting components from 1,755 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-08-01' and '2016-08-31'
#
# 	Found 2,604 calls
# 	Rows in month: 10,902
# 	Rows in month: 2,604
# Selecting components from 2,604 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-09-01' and '2016-09-30'
#
# 	Found 247 calls
# 	Rows in month: 1,047
# 	Rows in month: 247
# Selecting components from 247 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-10-01' and '2016-10-31'
#
# 	Found 1,485 calls
# 	Rows in month: 6,152
# 	Rows in month: 1,485
# Selecting components from 1,485 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-11-01' and '2016-11-30'
#
# 	Found 2,604 calls
# 	Rows in month: 10,902
# 	Rows in month: 2,604
# Selecting components from 2,604 transcripts
# Loading library list...
# Done
# Fetching ECs from 2016-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2016-12-01' and '2016-12-31'
#
# 	Found 236 calls
# 	Rows in month: 1,013
# 	Rows in month: 236
# Selecting components from 236 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-01-01' and '2017-01-31'
#
# 	Found 709 calls
# 	Rows in month: 3,087
# 	Rows in month: 709
# Selecting components from 709 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-02-01' and '2017-02-28'
#
# 	Found 2,752 calls
# 	Rows in month: 11,816
# 	Rows in month: 2,752
# Selecting components from 2,752 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-03-01' and '2017-03-31'
#
# 	Found 1,370 calls
# 	Rows in month: 5,810
# 	Rows in month: 1,370
# Selecting components from 1,370 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-04-01' and '2017-04-30'
#
# 	Found 1,364 calls
# 	Rows in month: 5,821
# 	Rows in month: 1,364
# Selecting components from 1,364 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-05-01' and '2017-05-31'
#
# 	Found 2,987 calls
# 	Rows in month: 12,496
# 	Rows in month: 2,943
# Selecting components from 2,943 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-06-01' and '2017-06-30'
#
# 	Found 263 calls
# 	Rows in month: 1,112
# 	Rows in month: 261
# Selecting components from 261 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-07-01' and '2017-07-31'
#
# 	Found 1,802 calls
# 	Rows in month: 7,413
# 	Rows in month: 1,699
# Selecting components from 1,699 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-08-01' and '2017-08-31'
#
# 	Found 3,537 calls
# 	Rows in month: 14,289
# 	Rows in month: 3,270
# Selecting components from 3,270 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-09-01' and '2017-09-30'
#
# 	Found 305 calls
# 	Rows in month: 1,329
# 	Rows in month: 303
# Selecting components from 303 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-10-01' and '2017-10-31'
#
# 	Found 1,767 calls
# 	Rows in month: 6,767
# 	Rows in month: 1,494
# Selecting components from 1,494 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-11-01' and '2017-11-30'
#
# 	Found 3,229 calls
# 	Rows in month: 12,140
# 	Rows in month: 2,738
# Selecting components from 2,738 transcripts
# Loading library list...
# Done
# Fetching ECs from 2017-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2017-12-01' and '2017-12-31'
#
# 	Found 229 calls
# 	Rows in month: 982
# 	Rows in month: 229
# Selecting components from 229 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-01-01' and '2018-01-31'
#
# 	Found 831 calls
# 	Rows in month: 3,608
# 	Rows in month: 831
# Selecting components from 831 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-02-01' and '2018-02-28'
#
# 	Found 3,177 calls
# 	Rows in month: 13,297
# 	Rows in month: 3,168
# Selecting components from 3,168 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-03-01' and '2018-03-31'
#
# 	Found 1,690 calls
# 	Rows in month: 7,098
# 	Rows in month: 1,688
# Selecting components from 1,688 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-04-01' and '2018-04-30'
#
# 	Found 1,647 calls
# 	Rows in month: 6,897
# 	Rows in month: 1,646
# Selecting components from 1,646 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-05-01' and '2018-05-31'
#
# 	Found 3,651 calls
# 	Rows in month: 15,371
# 	Rows in month: 3,641
# Selecting components from 3,641 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-06-01' and '2018-06-30'
#
# 	Found 285 calls
# 	Rows in month: 1,237
# 	Rows in month: 285
# Selecting components from 285 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-07-01' and '2018-07-31'
#
# 	Found 2,041 calls
# 	Rows in month: 9,187
# 	Rows in month: 2,041
# Selecting components from 2,041 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-08-01' and '2018-08-31'
#
# 	Found 3,728 calls
# 	Rows in month: 16,789
# 	Rows in month: 3,727
# Selecting components from 3,727 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-09-01' and '2018-09-30'
#
# 	Found 331 calls
# 	Rows in month: 1,474
# 	Rows in month: 331
# Selecting components from 331 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-10-01' and '2018-10-31'
#
# 	Found 2,005 calls
# 	Rows in month: 9,907
# 	Rows in month: 2,004
# Selecting components from 2,004 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-11-01' and '2018-11-30'
#
# 	Found 3,358 calls
# 	Rows in month: 15,100
# 	Rows in month: 3,350
# Selecting components from 3,350 transcripts
# Loading library list...
# Done
# Fetching ECs from 2018-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2018-12-01' and '2018-12-31'
#
# 	Found 240 calls
# 	Rows in month: 1,058
# 	Rows in month: 240
# Selecting components from 240 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-01-01' and '2019-01-31'
#
# 	Found 959 calls
# 	Rows in month: 4,419
# 	Rows in month: 959
# Selecting components from 959 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-02-01' and '2019-02-28'
#
# 	Found 3,518 calls
# 	Rows in month: 15,826
# 	Rows in month: 3,518
# Selecting components from 3,518 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-03-01' and '2019-03-31'
#
# 	Found 1,630 calls
# 	Rows in month: 7,220
# 	Rows in month: 1,630
# Selecting components from 1,630 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-04-01' and '2019-04-30'
#
# 	Found 1,696 calls
# 	Rows in month: 7,539
# 	Rows in month: 1,696
# Selecting components from 1,696 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-05-01' and '2019-05-31'
#
# 	Found 3,814 calls
# 	Rows in month: 16,689
# 	Rows in month: 3,814
# Selecting components from 3,814 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-06-01' and '2019-06-30'
#
# 	Found 295 calls
# 	Rows in month: 1,361
# 	Rows in month: 295
# Selecting components from 295 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-07-01' and '2019-07-31'
#
# 	Found 2,184 calls
# 	Rows in month: 10,199
# 	Rows in month: 2,184
# Selecting components from 2,184 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-08-01' and '2019-08-31'
#
# 	Found 3,827 calls
# 	Rows in month: 18,169
# 	Rows in month: 3,827
# Selecting components from 3,827 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-09-01' and '2019-09-30'
#
# 	Found 364 calls
# 	Rows in month: 1,741
# 	Rows in month: 364
# Selecting components from 364 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-10-01' and '2019-10-31'
#
# 	Found 2,195 calls
# 	Rows in month: 10,122
# 	Rows in month: 2,195
# Selecting components from 2,195 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-11-01' and '2019-11-30'
#
# 	Found 3,259 calls
# 	Rows in month: 14,625
# 	Rows in month: 3,259
# Selecting components from 3,259 transcripts
# Loading library list...
# Done
# Fetching ECs from 2019-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2019-12-01' and '2019-12-31'
#
# 	Found 281 calls
# 	Rows in month: 1,244
# 	Rows in month: 281
# Selecting components from 281 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-01-01' and '2020-01-31'
#
# 	Found 1,059 calls
# 	Rows in month: 5,065
# 	Rows in month: 1,059
# Selecting components from 1,059 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-02-01' and '2020-02-29'
#
# 	Found 3,968 calls
# 	Rows in month: 18,070
# 	Rows in month: 3,968
# Selecting components from 3,968 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-03-01' and '2020-03-31'
#
# 	Found 1,792 calls
# 	Rows in month: 8,266
# 	Rows in month: 1,792
# Selecting components from 1,792 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-04-01' and '2020-04-30'
#
# 	Found 1,723 calls
# 	Rows in month: 9,222
# 	Rows in month: 1,723
# Selecting components from 1,723 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-05-01' and '2020-05-31'
#
# 	Found 3,857 calls
# 	Rows in month: 16,854
# 	Rows in month: 3,857
# Selecting components from 3,857 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-06-01' and '2020-06-30'
#
# 	Found 782 calls
# 	Rows in month: 3,648
# 	Rows in month: 782
# Selecting components from 782 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-07-01' and '2020-07-31'
#
# 	Found 2,493 calls
# 	Rows in month: 10,868
# 	Rows in month: 2,493
# Selecting components from 2,493 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-08-01' and '2020-08-31'
#
# 	Found 4,130 calls
# 	Rows in month: 17,877
# 	Rows in month: 4,130
# Selecting components from 4,130 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-09-01' and '2020-09-30'
#
# 	Found 613 calls
# 	Rows in month: 2,604
# 	Rows in month: 613
# Selecting components from 613 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-10-01' and '2020-10-31'
#
# 	Found 2,185 calls
# 	Rows in month: 8,030
# 	Rows in month: 2,185
# Selecting components from 2,185 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-11-01' and '2020-11-30'
#
# 	Found 3,768 calls
# 	Rows in month: 10,373
# 	Rows in month: 3,767
# Selecting components from 3,767 transcripts
# Loading library list...
# Done
# Fetching ECs from 2020-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2020-12-01' and '2020-12-31'
#
# 	Found 343 calls
# 	Rows in month: 824
# 	Rows in month: 343
# Selecting components from 343 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-01-01' and '2021-01-31'
#
# 	Found 927 calls
# 	Rows in month: 3,286
# 	Rows in month: 927
# Selecting components from 927 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-02-01' and '2021-02-28'
#
# 	Found 3,970 calls
# 	Rows in month: 10,296
# 	Rows in month: 3,970
# Selecting components from 3,970 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-03-01' and '2021-03-31'
#
# 	Found 2,164 calls
# 	Rows in month: 4,871
# 	Rows in month: 2,164
# Selecting components from 2,164 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-04-01' and '2021-04-30'
#
# 	Found 1,974 calls
# 	Rows in month: 4,771
# 	Rows in month: 1,974
# Selecting components from 1,974 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-05-01' and '2021-05-31'
#
# 	Found 3,932 calls
# 	Rows in month: 10,902
# 	Rows in month: 3,932
# Selecting components from 3,932 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-06-01' and '2021-06-30'
#
# 	Found 542 calls
# 	Rows in month: 1,391
# 	Rows in month: 542
# Selecting components from 542 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-07-01' and '2021-07-31'
#
# 	Found 2,376 calls
# 	Rows in month: 6,546
# 	Rows in month: 2,376
# Selecting components from 2,376 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-08-01' and '2021-08-31'
#
# 	Found 4,631 calls
# 	Rows in month: 12,037
# 	Rows in month: 4,631
# Selecting components from 4,631 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-09-01' and '2021-09-30'
#
# 	Found 586 calls
# 	Rows in month: 1,585
# 	Rows in month: 586
# Selecting components from 586 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-10-01' and '2021-10-31'
#
# 	Found 2,035 calls
# 	Rows in month: 5,309
# 	Rows in month: 2,035
# Selecting components from 2,035 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-11-01' and '2021-11-30'
#
# 	Found 4,365 calls
# 	Rows in month: 11,605
# 	Rows in month: 4,365
# Selecting components from 4,365 transcripts
# Loading library list...
# Done
# Fetching ECs from 2021-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2021-12-01' and '2021-12-31'
#
# 	Found 352 calls
# 	Rows in month: 850
# 	Rows in month: 352
# Selecting components from 352 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-01-01' and '2022-01-31'
#
# 	Found 941 calls
# 	Rows in month: 2,578
# 	Rows in month: 941
# Selecting components from 941 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-02-01' and '2022-02-28'
#
# 	Found 4,225 calls
# 	Rows in month: 11,663
# 	Rows in month: 4,225
# Selecting components from 4,225 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-03-01' and '2022-03-31'
#
# 	Found 2,443 calls
# 	Rows in month: 6,893
# 	Rows in month: 2,443
# Selecting components from 2,443 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-04-01' and '2022-04-30'
#
# 	Found 1,873 calls
# 	Rows in month: 5,043
# 	Rows in month: 1,873
# Selecting components from 1,873 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-05-01' and '2022-05-31'
#
# 	Found 4,739 calls
# 	Rows in month: 12,538
# 	Rows in month: 4,739
# Selecting components from 4,739 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-06-01' and '2022-06-30'
#
# 	Found 444 calls
# 	Rows in month: 1,189
# 	Rows in month: 444
# Selecting components from 444 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-07-01' and '2022-07-31'
#
# 	Found 2,219 calls
# 	Rows in month: 5,730
# 	Rows in month: 2,219
# Selecting components from 2,219 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-08-01' and '2022-08-31'
#
# 	Found 5,033 calls
# 	Rows in month: 13,461
# 	Rows in month: 5,033
# Selecting components from 5,033 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-09-01' and '2022-09-30'
#
# 	Found 534 calls
# 	Rows in month: 1,563
# 	Rows in month: 534
# Selecting components from 534 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-10-01' and '2022-10-31'
#
# 	Found 1,865 calls
# 	Rows in month: 5,773
# 	Rows in month: 1,865
# Selecting components from 1,865 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-11-01' and '2022-11-30'
#
# 	Found 4,852 calls
# 	Rows in month: 13,317
# 	Rows in month: 4,852
# Selecting components from 4,852 transcripts
# Loading library list...
# Done
# Fetching ECs from 2022-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2022-12-01' and '2022-12-31'
#
# 	Found 340 calls
# 	Rows in month: 958
# 	Rows in month: 340
# Selecting components from 340 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-01-01' and '2023-01-31'
#
# 	Found 987 calls
# 	Rows in month: 2,562
# 	Rows in month: 987
# Selecting components from 987 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-02-01' and '2023-02-28'
#
# 	Found 4,237 calls
# 	Rows in month: 11,269
# 	Rows in month: 4,237
# Selecting components from 4,237 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-03-01' and '2023-03-31'
#
# 	Found 2,504 calls
# 	Rows in month: 6,655
# 	Rows in month: 2,504
# Selecting components from 2,504 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-04-01' and '2023-04-30'
#
# 	Found 1,807 calls
# 	Rows in month: 4,761
# 	Rows in month: 1,806
# Selecting components from 1,806 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-05-01' and '2023-05-31'
#
# 	Found 4,978 calls
# 	Rows in month: 13,893
# 	Rows in month: 4,978
# Selecting components from 4,978 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-06-01' and '2023-06-30'
#
# 	Found 424 calls
# 	Rows in month: 1,040
# 	Rows in month: 423
# Selecting components from 423 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-07-01' and '2023-07-31'
#
# 	Found 2,124 calls
# 	Rows in month: 5,607
# 	Rows in month: 2,115
# Selecting components from 2,115 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-08-01' and '2023-08-31'
#
# 	Found 5,347 calls
# 	Rows in month: 15,010
# 	Rows in month: 5,344
# Selecting components from 5,344 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-09-01' and '2023-09-30'
#
# 	Found 542 calls
# 	Rows in month: 1,396
# 	Rows in month: 541
# Selecting components from 541 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-10-01' and '2023-10-31'
#
# 	Found 2,010 calls
# 	Rows in month: 5,430
# 	Rows in month: 2,009
# Selecting components from 2,009 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-11-01' and '2023-11-30'
#
# 	Found 4,691 calls
# 	Rows in month: 13,079
# 	Rows in month: 4,690
# Selecting components from 4,690 transcripts
# Loading library list...
# Done
# Fetching ECs from 2023-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2023-12-01' and '2023-12-31'
#
# 	Found 312 calls
# 	Rows in month: 1,190
# 	Rows in month: 310
# Selecting components from 310 transcripts

# %%
for year in range(2024, 2025):
    annual_ec_data = save_ec_data(year)
    save_path = f'D:/EC_data/{year}_ec_data.parquet'
    annual_ec_data.to_parquet(save_path, index=False)
# Out:
# Loading library list...
# Done
# Fetching ECs from 2024-01 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-01-01' and '2024-01-31'
#
# 	Found 1,040 calls
# 	Rows in month: 3,267
# 	Rows in month: 1,038
# Selecting components from 1,038 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-02 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-02-01' and '2024-02-29'
#
# 	Found 4,534 calls
# 	Rows in month: 13,342
# 	Rows in month: 4,526
# Selecting components from 4,526 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-03 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-03-01' and '2024-03-31'
#
# 	Found 2,048 calls
# 	Rows in month: 5,817
# 	Rows in month: 2,040
# Selecting components from 2,040 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-04 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-04-01' and '2024-04-30'
#
# 	Found 2,036 calls
# 	Rows in month: 5,254
# 	Rows in month: 2,014
# Selecting components from 2,014 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-05 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-05-01' and '2024-05-31'
#
# 	Found 4,891 calls
# 	Rows in month: 13,234
# 	Rows in month: 4,842
# Selecting components from 4,842 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-06 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-06-01' and '2024-06-30'
#
# 	Found 406 calls
# 	Rows in month: 1,101
# 	Rows in month: 403
# Selecting components from 403 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-07 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-07-01' and '2024-07-31'
#
# 	Found 2,354 calls
# 	Rows in month: 6,228
# 	Rows in month: 2,345
# Selecting components from 2,345 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-08 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-08-01' and '2024-08-31'
#
# 	Found 4,940 calls
# 	Rows in month: 13,586
# 	Rows in month: 4,914
# Selecting components from 4,914 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-09 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-09-01' and '2024-09-30'
#
# 	Found 573 calls
# 	Rows in month: 1,519
# 	Rows in month: 573
# Selecting components from 573 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-10 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-10-01' and '2024-10-31'
#
# 	Found 2,506 calls
# 	Rows in month: 6,492
# 	Rows in month: 2,485
# Selecting components from 2,485 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-11 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-11-01' and '2024-11-30'
#
# 	Found 4,189 calls
# 	Rows in month: 11,138
# 	Rows in month: 4,130
# Selecting components from 4,130 transcripts
# Loading library list...
# Done
# Fetching ECs from 2024-12 ...
# Doing fetch
#     select companyid, keydevid, transcriptid, headline, keydeveventtypename,
#                           transcriptcollectiontypeid, transcriptcreationdate_utc from ciq.wrds_transcript_detail
#     where mostimportantdateutc between '2024-12-01' and '2024-12-31'
#
# 	Found 387 calls
# 	Rows in month: 946
# 	Rows in month: 373
# Selecting components from 373 transcripts
